# %%
import os 
import pandas as pd
from subprocess import call 
from collections import defaultdict
from Bio import SeqIO, AlignIO, SeqRecord, Seq

# %%
# Path to output directory
outpath = "../../results/phylogeny"

if not os.path.exists(outpath):
    os.mkdir(outpath)

# %% [markdown]
# ## Spruce Tree
#
# This data below represent the phylogenetic relationship of the haplotypes to one another. This is the final tree validated using bridging reads.

# %%
# Final tree from SPRUCE/MACHINA
cluster_relationships = pd.read_csv("../../results/phylogeny/filtered_spruce_tree.csv")
cluster_relationships['from'] = cluster_relationships['from'].replace('_', ' ', regex=True)
cluster_relationships['to'] = cluster_relationships['to'].replace('_', ' ', regex=True)
rename_clusters = {"Anc": "SSPE ancestor"}
cluster_relationships['from'] = cluster_relationships['from'].replace(rename_clusters)
cluster_relationships.drop(['tree', 'treenum'], axis=1, inplace=True)
cluster_relationships
# Out:
#              from          to
# 0             G-2   cluster 8
# 1             G-2  cluster 10
# 2             G-2   cluster 9
# 3             G-2  cluster 11
# 4             G-2   cluster 7
# 5             G-1   cluster 4
# 6             G-1   cluster 2
# 7             G-1   cluster 1
# 8             G-1   cluster 6
# 9             G-1   cluster 5
# 10            G-1   cluster 3
# 11           G-01         G-1
# 12           G-01       G-FC2
# 13      cluster 1  cluster 1a
# 14  SSPE ancestor         G-2
# 15  SSPE ancestor        G-01

# %% [markdown]
# ## Haplotype Mutations
#
# The following dataframe contains all of the variants in the 15 SSPE samples annotated by their haplotype.

# %%
# Import the mutations
haplotypes_df = pd.read_csv("../../results/variants/validated_variants.csv")

# Rename to standardize the naming scheme
rename_haplotypes = {"genome-1": "G-01", 
                     "genome-1-1": "G-1",
                     "genome-2": "G-2",
                     "cluster 6": "G-FC2",
                     "cluster 1": "cluster 1", 
                     "cluster 2": "cluster 2", 
                     "cluster 3": "cluster 3", 
                     "cluster 4": "cluster 4", 
                     "cluster 5": "cluster 1a", 
                     "cluster 7": "cluster 5", 
                     "cluster 8": "cluster 6", 
                     "cluster 9": "cluster 7", 
                     "cluster 10": "cluster 8", 
                     "cluster 11": "cluster 9", 
                     "cluster 12": "cluster 10", 
                     "cluster 13": "cluster 11"}

haplotypes_df['Haplotype'] = haplotypes_df['Haplotype'].replace(rename_haplotypes)

# We only need the mutations that have been assigned to a haplotype
haplotypes_df = haplotypes_df[~haplotypes_df.Haplotype.isin(['subclonal', 'both', 'fixed'])]
haplotypes_df = haplotypes_df.loc[:, ['POS', 'REF', 'ALT', 'Haplotype']].drop_duplicates()

haplotypes_df.head()
# Out:
#     POS REF ALT  Haplotype
# 0   537   T   C        G-2
# 1   684   C   T  cluster 4
# 5  1328   T   C        G-1
# 7  1632   G   A  cluster 8
# 9  2139   T   C       G-01

# %% [markdown]
# ## Make Haplotypes
#
# Iterate through the tree structure and add in the mutations to generate a dictionary of haplotype sequences.

# %%
# Function to recursively apply mutations
def apply_mutations(haplotype, tree, haplotype_df, haplotype_dict, reference):
    
    if haplotype in haplotype_dict:
        return haplotype_dict[haplotype]
    
    ancestor = tree[haplotype]
    ancestor_sequence = apply_mutations(ancestor, tree, haplotype_df, haplotype_dict, reference)
    
    haplotype_sequence = list(ancestor_sequence)  # Create a copy of the ancestor's sequence
    
    haplotype_mutations = haplotype_df[haplotype_df['Haplotype'] == haplotype]
    
    for _, mutation in haplotype_mutations.iterrows():
        pos, ref, alt = mutation['POS'], mutation['REF'], mutation['ALT']
        if haplotype_sequence[pos-1] == ref:
            haplotype_sequence[pos-1] = alt
        else:
            raise ValueError(f"Reference allele mismatch at position {pos} for {haplotype}")
    
    haplotype_sequence = ''.join(haplotype_sequence)
    haplotype_dict[haplotype] = haplotype_sequence
    
    return haplotype_sequence

# %%
# Import the reference sequence 
reference = [base for record in SeqIO.parse("../../config/ref/MeVChiTok-SSPE.fa", "fasta") for base in record.seq]

# Build the tree-like structure
tree = {}
for _, row in cluster_relationships.iterrows():
    tree[row['to']] = row['from']

# Initialize the haplotype dictionary with the known ancestor sequence
haplotype_dict = {'SSPE ancestor': ''.join(reference)}

# Create the DNA haplotypes_df for each haplotype based on the tree structure
for haplotype in haplotypes_df['Haplotype'].unique():
    if haplotype not in haplotype_dict:
        apply_mutations(haplotype, tree, haplotypes_df, haplotype_dict, reference)

# %% [markdown]
# ## Build a Tree
#
# Now, I'm going to take the haplotype sequences and build a tree using `iqtree`.

# %%
# Write out to a fasta file
haplotype_records = [SeqRecord.SeqRecord(Seq.Seq(seq), id = hap) for hap, seq in haplotype_dict.items()]
SeqIO.write(haplotype_records, os.path.join(outpath, "haplotype-sequences.fa"), "fasta")
# Out:
# 17

# %%
# Building the phylogeny with IQtree with 1000 bootstrap iterations with GTR+I+G (Invariable site plus discrete Gamma model) with asr
alignfasta = os.path.join(outpath, "haplotype-sequences.fa")
call(f"iqtree -s {alignfasta} -m GTR+I+G -bb 1000 -redo", shell=True)
# Out:
# IQ-TREE multicore version 2.1.4-beta COVID-edition for Linux 64-bit built Jun 24 2021
# Developed by Bui Quang Minh, James Barbetti, Nguyen Lam Tung,
# Olga Chernomor, Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    rhino02 (AVX512, FMA3, 754 GB RAM)
# Command: iqtree -s ../../results/phylogeny/haplotype-sequences.fa -m GTR+I+G -bb 1000 -redo
# Seed:    336298 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Fri Apr  7 10:14:06 2023
# Kernel:  AVX+FMA - 1 threads (72 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 72 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file ../../results/phylogeny/haplotype-sequences.fa ... Fasta format detected
# NOTE: Change sequence name 'SSPE ancestor <unknown description>' -> SSPE_ancestor
# NOTE: Change sequence name 'G-2 <unknown description>' -> G-2_<unknown
# NOTE: Change sequence name 'G-01 <unknown description>' -> G-01_<unknown
# NOTE: Change sequence name 'G-1 <unknown description>' -> G-1_<unknown
# NOTE: Change sequence name 'cluster 4 <unknown description>' -> cluster_4
# NOTE: Change sequence name 'cluster 8 <unknown description>' -> cluster_8
# NOTE: Change sequence name 'cluster 2 <unknown description>' -> cluster_2
# NOTE: Change sequence name 'G-FC2 <unknown description>' -> G-FC2_<unknown
# NOTE: Change sequence name 'cluster 1 <unknown description>' -> cluster_1
# NOTE: Change sequence name 'cluster 1a <unknown description>' -> cluster_1a
# NOTE: Change sequence name 'cluster 6 <unknown description>' -> cluster_6
# NOTE: Change sequence name 'cluster 5 <unknown description>' -> cluster_5
# NOTE: Change sequence name 'cluster 3 <unknown description>' -> cluster_3
# NOTE: Change sequence name 'cluster 10 <unknown description>' -> cluster_10
# NOTE: Change sequence name 'cluster 9 <unknown description>' -> cluster_9
# NOTE: Change sequence name 'cluster 11 <unknown description>' -> cluster_11
# NOTE: Change sequence name 'cluster 7 <unknown description>' -> cluster_7
# Alignment most likely contains DNA/RNA sequences
# Alignment has 17 sequences with 15894 columns, 56 distinct patterns
# 58 parsimony-informative, 66 singleton sites, 15770 constant sites
# WARNING: Some sequence names are changed as follows:
# G-2_<unknown -> G-2__unknown
# G-01_<unknown -> G-01__unknown
# G-1_<unknown -> G-1__unknown
# G-FC2_<unknown -> G-FC2__unknown
#
#                 Gap/Ambiguity  Composition  p-value
#    1  SSPE_ancestor     0.00%    passed     99.00%
#    2  G-2__unknown      0.00%    passed     99.81%
#    3  G-01__unknown     0.00%    passed    100.00%
#    4  G-1__unknown      0.00%    passed     99.82%
#    5  cluster_4         0.00%    passed     99.71%
#    6  cluster_8         0.00%    passed     99.77%
#    7  cluster_2         0.00%    passed     99.90%
#    8  G-FC2__unknown    0.00%    passed    100.00%
#    9  cluster_1         0.00%    passed     99.82%
#   10  cluster_1a        0.00%    passed     99.55%
#   11  cluster_6         0.00%    passed     99.77%
#   12  cluster_5         0.00%    passed     99.78%
#   13  cluster_3         0.00%    passed     99.80%
#   14  cluster_10        0.00%    passed     99.81%
#   15  cluster_9         0.00%    passed     99.63%
#   16  cluster_11        0.00%    passed     99.67%
#   17  cluster_7         0.00%    passed     99.81%
# ****  TOTAL             0.00%  0 sequences failed composition chi2 test (p-value<5%; df=3)
#
# Create initial parsimony tree by phylogenetic likelihood library (PLL)... 0.000 seconds
# Generating 1000 samples for ultrafast bootstrap (seed: 336298)...
#
# NOTE: 0 MB RAM (0 GB) is required!
# Estimate model parameters (epsilon = 0.100)
# Thoroughly optimizing +I+G parameters from 10 start values...
# Init pinv, alpha: 0.000, 1.000 / Estimate: 0.000, 0.732 / LogL: -23042.167
# Init pinv, alpha: 0.110, 1.000 / Estimate: 0.110, 0.996 / LogL: -23042.155
# Init pinv, alpha: 0.220, 1.000 / Estimate: 0.220, 1.476 / LogL: -23042.147
# Init pinv, alpha: 0.331, 1.000 / Estimate: 0.331, 2.629 / LogL: -23042.140
# Init pinv, alpha: 0.441, 1.000 / Estimate: 0.441, 9.211 / LogL: -23042.132
# Init pinv, alpha: 0.551, 1.000 / Estimate: 0.551, 998.422 / LogL: -23042.137
# Init pinv, alpha: 0.661, 1.000 / Estimate: 0.661, 998.439 / LogL: -23042.227
# Init pinv, alpha: 0.772, 1.000 / Estimate: 0.772, 998.444 / LogL: -23042.574
# Init pinv, alpha: 0.882, 1.000 / Estimate: 0.882, 998.446 / LogL: -23044.076
# Init pinv, alpha: 0.992, 1.000 / Estimate: 0.950, 998.447 / LogL: -23051.077
# Optimal pinv,alpha: 0.441, 9.211 / LogL: -23042.132
#
# Parameters optimization took 0.098 sec
#
# WARNING: Estimated model parameters are at boundary that can cause numerical instability!
#
# Computing ML distances based on estimated model parameters...
# Computing ML distances took 0.002166 sec (of wall-clock time) 0.002170 sec(of CPU time)
# Computing RapidNJ tree took 0.000171 sec (of wall-clock time) 0.000170 sec (of CPU time)
# Log-likelihood of RapidNJ tree: -23042.530
# --------------------------------------------------------------------
# |             INITIALIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Generating 98 parsimony trees... 0.034 second
# Computing log-likelihood of 98 initial trees ... 0.032 seconds
# Current best score: -23042.132
#
# Do NNI search on 20 best initial trees
# Estimate model parameters (epsilon = 0.100)
#
# WARNING: Estimated model parameters are at boundary that can cause numerical instability!
#
# BETTER TREE FOUND at iteration 1: -23042.129
# BETTER TREE FOUND at iteration 3: -23042.129
# Iteration 10 / LogL: -23042.129 / Time: 0h:0m:0s
# Iteration 20 / LogL: -23042.129 / Time: 0h:0m:0s
# Finish initializing candidate tree set (20)
# Current best tree score: -23042.129 / CPU time: 0.126
# Number of iterations: 20
# --------------------------------------------------------------------
# |               OPTIMIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# BETTER TREE FOUND at iteration 23: -23042.129
# BETTER TREE FOUND at iteration 29: -23042.129
# Iteration 30 / LogL: -23042.169 / Time: 0h:0m:0s (0h:0m:1s left)
# UPDATE BEST LOG-LIKELIHOOD: -23042.129
# Iteration 40 / LogL: -23042.129 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 50 / LogL: -23042.179 / Time: 0h:0m:0s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.085
# Iteration 60 / LogL: -23042.129 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 70 / LogL: -23042.191 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 80 / LogL: -23042.204 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 90 / LogL: -23042.168 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 100 / LogL: -23042.246 / Time: 0h:0m:0s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.100
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.920
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 110 / LogL: -23065.699 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 120 / LogL: -23042.129 / Time: 0h:0m:1s (0h:0m:0s left)
# BETTER TREE FOUND at iteration 127: -23042.129
# Iteration 130 / LogL: -23042.129 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 140 / LogL: -23042.168 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 150 / LogL: -23042.205 / Time: 0h:0m:1s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.100
# Iteration 160 / LogL: -23042.244 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 170 / LogL: -23042.179 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 180 / LogL: -23097.278 / Time: 0h:0m:1s (0h:0m:0s left)
# UPDATE BEST LOG-LIKELIHOOD: -23042.129
# Iteration 190 / LogL: -23042.129 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 200 / LogL: -23286.666 / Time: 0h:0m:1s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.257
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.964
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 210 / LogL: -23057.966 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 220 / LogL: -23042.174 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 230 / LogL: -23042.196 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 240 / LogL: -23042.168 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 250 / LogL: -23042.183 / Time: 0h:0m:2s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.257
# Iteration 260 / LogL: -23042.183 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 270 / LogL: -23042.155 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 280 / LogL: -23042.129 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 290 / LogL: -23042.191 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 300 / LogL: -23042.182 / Time: 0h:0m:2s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.257
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.973
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 310 / LogL: -23042.146 / Time: 0h:0m:2s (0h:0m:0s left)
# BETTER TREE FOUND at iteration 313: -23042.129
# Iteration 320 / LogL: -23042.156 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 330 / LogL: -23042.129 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 340 / LogL: -23042.129 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 350 / LogL: -23156.154 / Time: 0h:0m:3s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.257
# Iteration 360 / LogL: -23042.191 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 370 / LogL: -23042.129 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 380 / LogL: -23042.129 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 390 / LogL: -23042.129 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 400 / LogL: -23042.189 / Time: 0h:0m:3s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.257
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.966
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 410 / LogL: -23042.214 / Time: 0h:0m:3s (0h:0m:0s left)
# BETTER TREE FOUND at iteration 414: -23042.129
# Iteration 420 / LogL: -23042.175 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 430 / LogL: -23042.168 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 440 / LogL: -23042.176 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 450 / LogL: -23042.258 / Time: 0h:0m:3s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.257
# Iteration 460 / LogL: -23042.129 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 470 / LogL: -23042.129 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 480 / LogL: -23042.129 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 490 / LogL: -23042.129 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 500 / LogL: -23042.204 / Time: 0h:0m:4s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.257
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.957
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 510 / LogL: -23042.226 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 520 / LogL: -23042.189 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 530 / LogL: -23042.129 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 540 / LogL: -23049.895 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 550 / LogL: -23065.668 / Time: 0h:0m:4s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.275
# Iteration 560 / LogL: -23042.160 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 570 / LogL: -23049.951 / Time: 0h:0m:5s (0h:0m:0s left)
# UPDATE BEST LOG-LIKELIHOOD: -23042.129
# Iteration 580 / LogL: -23042.129 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 590 / LogL: -23042.129 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 600 / LogL: -23163.869 / Time: 0h:0m:5s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.357
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.962
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 610 / LogL: -23042.129 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 620 / LogL: -23042.179 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 630 / LogL: -23042.129 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 640 / LogL: -23042.129 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 650 / LogL: -23042.156 / Time: 0h:0m:5s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.357
# Iteration 660 / LogL: -23049.943 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 670 / LogL: -23042.172 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 680 / LogL: -23042.173 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 690 / LogL: -23065.687 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 700 / LogL: -23042.229 / Time: 0h:0m:6s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.357
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.982
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# BETTER TREE FOUND at iteration 706: -23042.129
# Iteration 710 / LogL: -23058.021 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 720 / LogL: -23042.189 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 730 / LogL: -23065.707 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 740 / LogL: -23042.180 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 750 / LogL: -23042.187 / Time: 0h:0m:7s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.357
# BETTER TREE FOUND at iteration 754: -23042.129
# Iteration 760 / LogL: -23156.182 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 770 / LogL: -23042.147 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 780 / LogL: -23042.129 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 790 / LogL: -23042.256 / Time: 0h:0m:7s (0h:0m:0s left)
# UPDATE BEST LOG-LIKELIHOOD: -23042.129
# Iteration 800 / LogL: -23065.713 / Time: 0h:0m:7s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.357
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.966
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 810 / LogL: -23042.213 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 820 / LogL: -23049.955 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 830 / LogL: -23042.129 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 840 / LogL: -23057.966 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 850 / LogL: -23049.865 / Time: 0h:0m:8s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.357
# Iteration 860 / LogL: -23042.165 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 870 / LogL: -23042.129 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 880 / LogL: -23049.869 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 890 / LogL: -23042.261 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 900 / LogL: -23042.193 / Time: 0h:0m:9s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.378
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.961
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 910 / LogL: -23042.191 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 920 / LogL: -23042.154 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 930 / LogL: -23042.129 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 940 / LogL: -23042.160 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 950 / LogL: -23049.841 / Time: 0h:0m:9s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.378
# Iteration 960 / LogL: -23042.192 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 970 / LogL: -23042.129 / Time: 0h:0m:10s (0h:0m:0s left)
# Iteration 980 / LogL: -23042.129 / Time: 0h:0m:10s (0h:0m:0s left)
# Iteration 990 / LogL: -23042.129 / Time: 0h:0m:10s (0h:0m:0s left)
# Iteration 1000 / LogL: -23042.129 / Time: 0h:0m:10s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.625
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.962
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# WARNING: bootstrap analysis did not converge. You should rerun with higher number of iterations (-nm option)
# TREE SEARCH COMPLETED AFTER 1001 ITERATIONS / Time: 0h:0m:10s
#
# --------------------------------------------------------------------
# |                    FINALIZING TREE SEARCH                        |
# --------------------------------------------------------------------
# Performs final model parameters optimization
# Estimate model parameters (epsilon = 0.010)
# 1. Initial log-likelihood: -23042.129
# Optimal log-likelihood: -23042.127
# Rate parameters:  A-C: 7.68413  A-G: 38.49763  A-T: 5.35144  C-G: 1.30868  C-T: 100.00000  G-T: 1.00000
# Base frequencies:  A: 0.292  C: 0.241  G: 0.235  T: 0.232
# Proportion of invariable sites: 0.441
# Gamma shape alpha: 9.211
# Parameters optimization took 1 rounds (0.002 sec)
#
# WARNING: Estimated model parameters are at boundary that can cause numerical instability!
#
# BEST SCORE FOUND : -23042.127
# Creating bootstrap support values...
# Split supports printed to NEXUS file ../../results/phylogeny/haplotype-sequences.fa.splits.nex
# Total tree length: 0.008
#
# Total number of iterations: 1001
# CPU time used for tree search: 9.866 sec (0h:0m:9s)
# Wall-clock time used for tree search: 10.284 sec (0h:0m:10s)
# Total CPU time used: 10.009 sec (0h:0m:10s)
# Total wall-clock time used: 10.453 sec (0h:0m:10s)
#
# Computing bootstrap consensus tree...
# Reading input file ../../results/phylogeny/haplotype-sequences.fa.splits.nex...
# 17 taxa and 187 splits.
# Consensus tree written to ../../results/phylogeny/haplotype-sequences.fa.contree
# Reading input trees file ../../results/phylogeny/haplotype-sequences.fa.contree
# Log-likelihood of consensus tree: -23042.588
#
# Analysis results written to:
#   IQ-TREE report:                ../../results/phylogeny/haplotype-sequences.fa.iqtree
#   Maximum-likelihood tree:       ../../results/phylogeny/haplotype-sequences.fa.treefile
#   Likelihood distances:          ../../results/phylogeny/haplotype-sequences.fa.mldist
#
# Ultrafast bootstrap approximation results written to:
#   Split support values:          ../../results/phylogeny/haplotype-sequences.fa.splits.nex
#   Consensus tree:                ../../results/phylogeny/haplotype-sequences.fa.contree
#   Screen log file:               ../../results/phylogeny/haplotype-sequences.fa.log
#
# Date and Time: Fri Apr  7 10:14:16 2023
# 0
