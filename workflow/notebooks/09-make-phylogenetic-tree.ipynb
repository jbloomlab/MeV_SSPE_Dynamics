# %% [markdown]
# # Phylogenetic Analysis
#
# The goal of this notebook is to perform phylogenetic inference on the haplotypes identified in the brain.
#
# **Requirements:**
# Make sure you have `Biopython`, `MAFFT`, and `ETE3` installed in your environment.

# %%
import os 
import pandas as pd
import numpy as np
from copy import deepcopy
from subprocess import call 
from Bio import SeqIO, AlignIO, SeqRecord, Seq
from Bio.Align.Applications import MafftCommandline 

# from ete3 import Tree, TreeStyle, NodeStyle, TextFace, SequenceFace, CircleFace, faces, AttrFace

# %%
# Path to output directory
outpath = "../../results/phylogeny"

if not os.path.exists(outpath):
    os.mkdir(outpath)

# %% [markdown]
# ## Make haplotypes from mutations
#
# I'll take the mutations from the variant calling analysis and make the haplotypes using the reference genome.

# %%
# Final tree from SPRUCE/MACHINA
cluster_relationships = pd.read_csv("../../results/phylogeny/filtered_spruce_tree.csv")
cluster_relationships['from'] = cluster_relationships['from'].replace('_', ' ', regex=True)
cluster_relationships['to'] = cluster_relationships['to'].replace('_', ' ', regex=True)
rename_clusters = {"Anc": "SSPE ancestor"}
cluster_relationships['from'] = cluster_relationships['from'].replace(rename_clusters)

# SSPE reference
reference = [base for record in SeqIO.parse("../../config/ref/MeVChiTok-SSPE.fa", "fasta") for base in record.seq]

# Import the mutations
haplotypes_df = pd.read_csv("../../results/variants/validated_variants.csv")
rename_haplotypes = {"genome-1": "genome 01", 
                     "genome-1-1": "genome 1",
                     "genome-2": "genome 2"}
haplotypes_df['Haplotype'] = haplotypes_df['Haplotype'].replace(rename_haplotypes)

# We only need the mutations that have been assigned to a haplotype
haplotypes_df = haplotypes_df[~haplotypes_df.Haplotype.isin(['subclonal', 'both'])]

haplotypes_df.head()
# Out:
#     POS REF ALT      AF      DP      Effect Gene_Name  AA_Change Accession  \
# 0   537   T   C  0.3265  132284    Missense         N  Ser144Pro    SSPE_1
# 1   684   C   T  0.1140  127945  Synonymous         N  Leu193Leu    SSPE_1
# 5  1328   T   C  0.6809  131283  Synonymous         N  Ser407Ser    SSPE_1
# 7  1632   G   A  0.3126  121322    Missense         N  Gly509Ser    SSPE_1
# 9  2139   T   C  0.6473   62808  Synonymous     P/V/C  His111His    SSPE_1
#
#    Tissue     SNP   Gene     Cluster Background   Haplotype
# 0  SSPE 1   T537C      N    genome-2   genome-2    genome 2
# 1  SSPE 1   C684T      N   cluster 1   genome-1   cluster 4
# 5  SSPE 1  T1328C      N  genome-1-1   genome-1    genome 1
# 7  SSPE 1  G1632A      N   cluster 7   genome-2  cluster 10
# 9  SSPE 1  T2139C  P/V/C    genome-1   genome-1   genome 01

# %%
def make_haplotype(to_node, from_seq):
    """
    Add the SNPs the ancestor to build a haplotype.
    """
    
    # SNPs for a given haplotype
    snps_df = haplotypes_df[haplotypes_df.Haplotype == to_node]
    
    # get a list of tuples for the SNPs
    snps = {(pos, alt) for pos, alt in zip(snps_df.POS, snps_df.ALT)}
    
    # Copy the reference 
    haplotype = deepcopy(from_seq)
    
    # Change the mutation in the list.
    for pos, alt in snps:
        from_seq[pos - 1] = alt
        
    return haplotype
    

def traverse_tree(node, tree_df, haplotypes):
    """
    Traverse the finalized SPRUCE tree and build the haplotypes into a 
    dictionary before alignment.
    """
    children = tree_df[tree_df['from'] == node]

    if children.empty:
        return haplotypes

    for _, row in children.iterrows():
        from_node = row['from']
        to_node = row['to']
        from_seq = haplotypes[from_node]
        print(f"Makeing haplotype for {to_node} using background {from_node}")
        new_haplotype = make_haplotype(to_node, from_seq)
        haplotypes[to_node] = new_haplotype
        traverse_tree(to_node, tree_df, haplotypes)

    return haplotypes

# %% [markdown]
# ### Haplotype Relationships

# %% [markdown]
# I'll make the fasta files for each haplotype by cumulativley building them along the tree that we deteremine using `SPRUCE` filtered down using briding reads.

# %%
cluster_relationships
# Out:
#              from          to    tree  treenum
# 0        genome 2  cluster 10  tree 1        1
# 1        genome 2  cluster 12  tree 1        1
# 2        genome 2  cluster 11  tree 1        1
# 3        genome 2  cluster 13  tree 1        1
# 4        genome 2   cluster 9  tree 1        1
# 5        genome 1   cluster 4  tree 1        1
# 6        genome 1   cluster 2  tree 1        1
# 7        genome 1   cluster 1  tree 1        1
# 8        genome 1   cluster 8  tree 1        1
# 9        genome 1   cluster 7  tree 1        1
# 10       genome 1   cluster 3  tree 1        1
# 11      genome 01    genome 1  tree 1        1
# 12      genome 01   cluster 6  tree 1        1
# 13      cluster 1   cluster 5  tree 1        1
# 14  SSPE ancestor    genome 2  tree 1        1
# 15  SSPE ancestor   genome 01  tree 1        1

# %%
# Root is the SSPE Reference Sequence
root = 'SSPE ancestor'
haplotypes = {}
haplotypes[root] = reference
# Build the haplotypes 
resulting_haplotypes = traverse_tree(root, cluster_relationships, haplotypes)
haplotype_seqs = {hap: "".join(nt for nt in seq) for hap, seq in resulting_haplotypes.items()}
# Out:
# Makeing haplotype for genome 2 using background SSPE ancestor
# Makeing haplotype for cluster 10 using background genome 2
# Makeing haplotype for cluster 12 using background genome 2
# Makeing haplotype for cluster 11 using background genome 2
# Makeing haplotype for cluster 13 using background genome 2
# Makeing haplotype for cluster 9 using background genome 2
# Makeing haplotype for genome 01 using background SSPE ancestor
# Makeing haplotype for genome 1 using background genome 01
# Makeing haplotype for cluster 4 using background genome 1
# Makeing haplotype for cluster 2 using background genome 1
# Makeing haplotype for cluster 1 using background genome 1
# Makeing haplotype for cluster 5 using background cluster 1
# Makeing haplotype for cluster 8 using background genome 1
# Makeing haplotype for cluster 7 using background genome 1
# Makeing haplotype for cluster 3 using background genome 1
# Makeing haplotype for cluster 6 using background genome 01

# %%
haplotype_seqs['cluster 9'] == haplotype_seqs['genome 2']
# Out:
# False

# %%
# Write out to a fasta file
haplotype_records = [SeqRecord.SeqRecord(Seq.Seq(seq), id = hap) for hap, seq in haplotype_seqs.items()]
SeqIO.write(haplotype_records, os.path.join(outpath, "haplotype-sequences.fa"), "fasta")
# Out:
# 17

# %% [markdown]
# ## Visualize the Tree

# %% [markdown]
# Make a tree with the Fasta file of each terminal haplotype. These are alredady aligned by the nature of how I made them.

# %%
# Building the phylogeny with IQtree with 1000 bootstrap iterations with GTR+I+G (Invariable site plus discrete Gamma model) with asr
alignfasta = os.path.join(outpath, "haplotype-sequences.fa")
call(f"iqtree -s {alignfasta} -m GTR+I+G -bb 1000 -redo", shell=True)
# Out:
# IQ-TREE multicore version 2.1.4-beta COVID-edition for Linux 64-bit built Jun 24 2021
# Developed by Bui Quang Minh, James Barbetti, Nguyen Lam Tung,
# Olga Chernomor, Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    rhino02 (AVX512, FMA3, 754 GB RAM)
# Command: iqtree -s ../../results/phylogeny/haplotype-sequences.fa -m GTR+I+G -bb 1000 -redo
# Seed:    55499 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Fri Mar 31 15:04:29 2023
# Kernel:  AVX+FMA - 1 threads (72 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 72 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file ../../results/phylogeny/haplotype-sequences.fa ... Fasta format detected
# NOTE: Change sequence name 'SSPE ancestor <unknown description>' -> SSPE_ancestor
# NOTE: Change sequence name 'genome 2 <unknown description>' -> genome_2
# NOTE: Change sequence name 'cluster 10 <unknown description>' -> cluster_10
# NOTE: Change sequence name 'cluster 12 <unknown description>' -> cluster_12
# NOTE: Change sequence name 'cluster 11 <unknown description>' -> cluster_11
# NOTE: Change sequence name 'cluster 13 <unknown description>' -> cluster_13
# NOTE: Change sequence name 'cluster 9 <unknown description>' -> cluster_9
# NOTE: Change sequence name 'genome 01 <unknown description>' -> genome_01
# NOTE: Change sequence name 'genome 1 <unknown description>' -> genome_1
# NOTE: Change sequence name 'cluster 4 <unknown description>' -> cluster_4
# NOTE: Change sequence name 'cluster 2 <unknown description>' -> cluster_2
# NOTE: Change sequence name 'cluster 1 <unknown description>' -> cluster_1
# NOTE: Change sequence name 'cluster 5 <unknown description>' -> cluster_5
# NOTE: Change sequence name 'cluster 8 <unknown description>' -> cluster_8
# NOTE: Change sequence name 'cluster 7 <unknown description>' -> cluster_7
# NOTE: Change sequence name 'cluster 3 <unknown description>' -> cluster_3
# NOTE: Change sequence name 'cluster 6 <unknown description>' -> cluster_6
# Alignment most likely contains DNA/RNA sequences
# Alignment has 17 sequences with 15894 columns, 46 distinct patterns
# 55 parsimony-informative, 23 singleton sites, 15816 constant sites
#                Gap/Ambiguity  Composition  p-value
#    1  SSPE_ancestor    0.00%    passed    100.00%
#    2  genome_2         0.00%    passed     99.92%
#    3  cluster_10       0.00%    passed    100.00%
#    4  cluster_12       0.00%    passed    100.00%
#    5  cluster_11       0.00%    passed     99.99%
#    6  cluster_13       0.00%    passed     99.97%
#    7  cluster_9        0.00%    passed     99.92%
#    8  genome_01        0.00%    passed     99.93%
#    9  genome_1         0.00%    passed    100.00%
#   10  cluster_4        0.00%    passed    100.00%
#   11  cluster_2        0.00%    passed    100.00%
#   12  cluster_1        0.00%    passed     99.97%
#   13  cluster_5        0.00%    passed     99.99%
#   14  cluster_8        0.00%    passed    100.00%
#   15  cluster_7        0.00%    passed    100.00%
#   16  cluster_3        0.00%    passed    100.00%
#   17  cluster_6        0.00%    passed     99.86%
# ****  TOTAL            0.00%  0 sequences failed composition chi2 test (p-value<5%; df=3)
# NOTE: cluster_10 is identical to SSPE_ancestor but kept for subsequent analysis
# NOTE: 1 identical sequences (see below) will be ignored for subsequent analysis
# NOTE: cluster_4 (identical to SSPE_ancestor) is ignored but added at the end
# Alignment was printed to ../../results/phylogeny/haplotype-sequences.fa.uniqueseq.phy
#
# For your convenience alignment with unique sequences printed to ../../results/phylogeny/haplotype-sequences.fa.uniqueseq.phy
#
# Create initial parsimony tree by phylogenetic likelihood library (PLL)... 0.000 seconds
# Generating 1000 samples for ultrafast bootstrap (seed: 55499)...
#
# NOTE: 0 MB RAM (0 GB) is required!
# Estimate model parameters (epsilon = 0.100)
# Thoroughly optimizing +I+G parameters from 10 start values...
# Init pinv, alpha: 0.000, 1.000 / Estimate: 0.000, 0.020 / LogL: -22690.462
# Init pinv, alpha: 0.111, 1.000 / Estimate: 0.111, 0.020 / LogL: -22690.390
# Init pinv, alpha: 0.221, 1.000 / Estimate: 0.221, 0.054 / LogL: -22690.369
# Init pinv, alpha: 0.332, 1.000 / Estimate: 0.332, 0.167 / LogL: -22690.338
# Init pinv, alpha: 0.442, 1.000 / Estimate: 0.442, 0.284 / LogL: -22690.309
# Init pinv, alpha: 0.553, 1.000 / Estimate: 0.553, 0.490 / LogL: -22690.290
# Init pinv, alpha: 0.663, 1.000 / Estimate: 0.663, 1.004 / LogL: -22690.281
# Init pinv, alpha: 0.774, 1.000 / Estimate: 0.774, 5.143 / LogL: -22690.255
# Init pinv, alpha: 0.885, 1.000 / Estimate: 0.884, 998.441 / LogL: -22690.400
# Init pinv, alpha: 0.995, 1.000 / Estimate: 0.975, 998.447 / LogL: -22695.945
# Optimal pinv,alpha: 0.774, 5.143 / LogL: -22690.255
#
# Parameters optimization took 0.067 sec
# Computing ML distances based on estimated model parameters...
# Computing ML distances took 0.002608 sec (of wall-clock time) 0.002614 sec(of CPU time)
# Computing RapidNJ tree took 0.000210 sec (of wall-clock time) 0.000174 sec (of CPU time)
# Log-likelihood of RapidNJ tree: -22757.247
# --------------------------------------------------------------------
# |             INITIALIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Generating 98 parsimony trees... 0.045 second
# Computing log-likelihood of 98 initial trees ... 0.031 seconds
# Current best score: -22690.255
#
# Do NNI search on 20 best initial trees
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 1: -22690.250
# Iteration 10 / LogL: -22690.251 / Time: 0h:0m:0s
# Iteration 20 / LogL: -22690.251 / Time: 0h:0m:0s
# Finish initializing candidate tree set (6)
# Current best tree score: -22690.250 / CPU time: 0.130
# Number of iterations: 20
# --------------------------------------------------------------------
# |               OPTIMIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Iteration 30 / LogL: -22690.273 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 40 / LogL: -22697.986 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 50 / LogL: -22690.331 / Time: 0h:0m:0s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22717.638
# Iteration 60 / LogL: -22690.273 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 70 / LogL: -22690.418 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 80 / LogL: -22690.443 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 90 / LogL: -22690.374 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 100 / LogL: -22690.295 / Time: 0h:0m:0s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22717.832
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.997
# TREE SEARCH COMPLETED AFTER 102 ITERATIONS / Time: 0h:0m:0s
#
# --------------------------------------------------------------------
# |                    FINALIZING TREE SEARCH                        |
# --------------------------------------------------------------------
# Performs final model parameters optimization
# Estimate model parameters (epsilon = 0.010)
# 1. Initial log-likelihood: -22690.250
# 2. Current log-likelihood: -22690.228
# 3. Current log-likelihood: -22690.211
# Optimal log-likelihood: -22690.205
# Rate parameters:  A-C: 1.49906  A-G: 6.36554  A-T: 0.78613  C-G: 0.31203  C-T: 13.11669  G-T: 1.00000
# Base frequencies:  A: 0.291  C: 0.241  G: 0.236  T: 0.232
# Proportion of invariable sites: 0.774
# Gamma shape alpha: 5.138
# Parameters optimization took 3 rounds (0.003 sec)
# BEST SCORE FOUND : -22690.205
# Creating bootstrap support values...
# Split supports printed to NEXUS file ../../results/phylogeny/haplotype-sequences.fa.splits.nex
# Total tree length: 0.005
#
# Total number of iterations: 102
# CPU time used for tree search: 0.812 sec (0h:0m:0s)
# Wall-clock time used for tree search: 0.837 sec (0h:0m:0s)
# Total CPU time used: 0.922 sec (0h:0m:0s)
# Total wall-clock time used: 0.979 sec (0h:0m:0s)
#
# Computing bootstrap consensus tree...
# Reading input file ../../results/phylogeny/haplotype-sequences.fa.splits.nex...
# 16 taxa and 58 splits.
# Consensus tree written to ../../results/phylogeny/haplotype-sequences.fa.contree
# Reading input trees file ../../results/phylogeny/haplotype-sequences.fa.contree
# Log-likelihood of consensus tree: -22690.666
#
# Analysis results written to:
#   IQ-TREE report:                ../../results/phylogeny/haplotype-sequences.fa.iqtree
#   Maximum-likelihood tree:       ../../results/phylogeny/haplotype-sequences.fa.treefile
#   Likelihood distances:          ../../results/phylogeny/haplotype-sequences.fa.mldist
#
# Ultrafast bootstrap approximation results written to:
#   Split support values:          ../../results/phylogeny/haplotype-sequences.fa.splits.nex
#   Consensus tree:                ../../results/phylogeny/haplotype-sequences.fa.contree
#   Screen log file:               ../../results/phylogeny/haplotype-sequences.fa.log
#
# Date and Time: Fri Mar 31 15:04:30 2023
# 0
