# %%
import os 
import pandas as pd
from subprocess import call 
from collections import defaultdict
from Bio import SeqIO, AlignIO, SeqRecord, Seq

# %%
# Path to output directory
outpath = "../../results/phylogeny"

if not os.path.exists(outpath):
    os.mkdir(outpath)

# %% [markdown]
# ## Spruce Tree
#
# This data below represent the phylogenetic relationship of the haplotypes to one another. This is the final tree validated using bridging reads.

# %%
# Final tree from SPRUCE/MACHINA
cluster_relationships = pd.read_csv("../../results/phylogeny/filtered_spruce_tree.csv")
cluster_relationships['from'] = cluster_relationships['from'].replace('_', ' ', regex=True)
cluster_relationships['to'] = cluster_relationships['to'].replace('_', ' ', regex=True)
rename_clusters = {"Anc": "SSPE ancestor"}
cluster_relationships['from'] = cluster_relationships['from'].replace(rename_clusters)
cluster_relationships.drop(['tree', 'treenum'], axis=1, inplace=True)
cluster_relationships
# Out:
#              from          to
# 0        genome 2  cluster 10
# 1        genome 2  cluster 12
# 2        genome 2  cluster 11
# 3        genome 2  cluster 13
# 4        genome 2   cluster 9
# 5        genome 1   cluster 4
# 6        genome 1   cluster 2
# 7        genome 1   cluster 1
# 8        genome 1   cluster 8
# 9        genome 1   cluster 7
# 10       genome 1   cluster 3
# 11      genome 01    genome 1
# 12      genome 01   cluster 6
# 13      cluster 1   cluster 5
# 14  SSPE ancestor    genome 2
# 15  SSPE ancestor   genome 01

# %% [markdown]
# ## Haplotype Mutations
#
# The following dataframe contains all of the variants in the 15 SSPE samples annotated by their haplotype.

# %%
# Import the mutations
haplotypes_df = pd.read_csv("../../results/variants/validated_variants.csv")

# Rename to standardize the naming scheme
rename_haplotypes = {"genome-1": "genome 01", 
                     "genome-1-1": "genome 1",
                     "genome-2": "genome 2"}
haplotypes_df['Haplotype'] = haplotypes_df['Haplotype'].replace(rename_haplotypes)

# We only need the mutations that have been assigned to a haplotype
haplotypes_df = haplotypes_df[~haplotypes_df.Haplotype.isin(['subclonal', 'both', 'fixed'])]
haplotypes_df = haplotypes_df.loc[:, ['POS', 'REF', 'ALT', 'Haplotype']].drop_duplicates()

haplotypes_df.head()
# Out:
#     POS REF ALT   Haplotype
# 0   537   T   C    genome 2
# 1   684   C   T   cluster 4
# 5  1328   T   C    genome 1
# 7  1632   G   A  cluster 10
# 9  2139   T   C   genome 01

# %% [markdown]
# ## Make Haplotypes
#
# Iterate through the tree structure and add in the mutations to generate a dictionary of haplotype sequences.

# %%
# Function to recursively apply mutations
def apply_mutations(haplotype, tree, haplotype_df, haplotype_dict, reference):
    
    if haplotype in haplotype_dict:
        return haplotype_dict[haplotype]
    
    ancestor = tree[haplotype]
    ancestor_sequence = apply_mutations(ancestor, tree, haplotype_df, haplotype_dict, reference)
    
    haplotype_sequence = list(ancestor_sequence)  # Create a copy of the ancestor's sequence
    
    haplotype_mutations = haplotype_df[haplotype_df['Haplotype'] == haplotype]
    
    for _, mutation in haplotype_mutations.iterrows():
        pos, ref, alt = mutation['POS'], mutation['REF'], mutation['ALT']
        if haplotype_sequence[pos-1] == ref:
            haplotype_sequence[pos-1] = alt
        else:
            raise ValueError(f"Reference allele mismatch at position {pos} for {haplotype}")
    
    haplotype_sequence = ''.join(haplotype_sequence)
    haplotype_dict[haplotype] = haplotype_sequence
    
    return haplotype_sequence

# %%
# Import the reference sequence 
reference = [base for record in SeqIO.parse("../../config/ref/MeVChiTok-SSPE.fa", "fasta") for base in record.seq]

# Build the tree-like structure
tree = {}
for _, row in cluster_relationships.iterrows():
    tree[row['to']] = row['from']

# Initialize the haplotype dictionary with the known ancestor sequence
haplotype_dict = {'SSPE ancestor': ''.join(reference)}

# Create the DNA haplotypes_df for each haplotype based on the tree structure
for haplotype in haplotypes_df['Haplotype'].unique():
    if haplotype not in haplotype_dict:
        apply_mutations(haplotype, tree, haplotypes_df, haplotype_dict, reference)

# %% [markdown]
# ## Build a Tree
#
# Now, I'm going to take the haplotype sequences and build a tree using `iqtree`.

# %%
# Write out to a fasta file
haplotype_records = [SeqRecord.SeqRecord(Seq.Seq(seq), id = hap) for hap, seq in haplotype_dict.items()]
SeqIO.write(haplotype_records, os.path.join(outpath, "haplotype-sequences.fa"), "fasta")
# Out:
# 17

# %%
# Building the phylogeny with IQtree with 1000 bootstrap iterations with GTR+I+G (Invariable site plus discrete Gamma model) with asr
alignfasta = os.path.join(outpath, "haplotype-sequences.fa")
call(f"iqtree -s {alignfasta} -m GTR+I+G -bb 1000 -redo", shell=True)
# Out:
# IQ-TREE multicore version 2.1.4-beta COVID-edition for Linux 64-bit built Jun 24 2021
# Developed by Bui Quang Minh, James Barbetti, Nguyen Lam Tung,
# Olga Chernomor, Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    rhino02 (AVX512, FMA3, 754 GB RAM)
# Command: iqtree -s ../../results/phylogeny/haplotype-sequences.fa -m GTR+I+G -bb 1000 -redo
# Seed:    941483 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Mon Apr  3 11:22:01 2023
# Kernel:  AVX+FMA - 1 threads (72 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 72 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file ../../results/phylogeny/haplotype-sequences.fa ... Fasta format detected
# NOTE: Change sequence name 'SSPE ancestor <unknown description>' -> SSPE_ancestor
# NOTE: Change sequence name 'genome 2 <unknown description>' -> genome_2
# NOTE: Change sequence name 'genome 01 <unknown description>' -> genome_01
# NOTE: Change sequence name 'genome 1 <unknown description>' -> genome_1
# NOTE: Change sequence name 'cluster 4 <unknown description>' -> cluster_4
# NOTE: Change sequence name 'cluster 10 <unknown description>' -> cluster_10
# NOTE: Change sequence name 'cluster 2 <unknown description>' -> cluster_2
# NOTE: Change sequence name 'cluster 6 <unknown description>' -> cluster_6
# NOTE: Change sequence name 'cluster 1 <unknown description>' -> cluster_1
# NOTE: Change sequence name 'cluster 5 <unknown description>' -> cluster_5
# NOTE: Change sequence name 'cluster 8 <unknown description>' -> cluster_8
# NOTE: Change sequence name 'cluster 7 <unknown description>' -> cluster_7
# NOTE: Change sequence name 'cluster 3 <unknown description>' -> cluster_3
# NOTE: Change sequence name 'cluster 12 <unknown description>' -> cluster_12
# NOTE: Change sequence name 'cluster 11 <unknown description>' -> cluster_11
# NOTE: Change sequence name 'cluster 13 <unknown description>' -> cluster_13
# NOTE: Change sequence name 'cluster 9 <unknown description>' -> cluster_9
# Alignment most likely contains DNA/RNA sequences
# Alignment has 17 sequences with 15894 columns, 56 distinct patterns
# 58 parsimony-informative, 66 singleton sites, 15770 constant sites
#                Gap/Ambiguity  Composition  p-value
#    1  SSPE_ancestor    0.00%    passed     99.00%
#    2  genome_2         0.00%    passed     99.81%
#    3  genome_01        0.00%    passed    100.00%
#    4  genome_1         0.00%    passed     99.82%
#    5  cluster_4        0.00%    passed     99.71%
#    6  cluster_10       0.00%    passed     99.77%
#    7  cluster_2        0.00%    passed     99.90%
#    8  cluster_6        0.00%    passed    100.00%
#    9  cluster_1        0.00%    passed     99.82%
#   10  cluster_5        0.00%    passed     99.55%
#   11  cluster_8        0.00%    passed     99.77%
#   12  cluster_7        0.00%    passed     99.78%
#   13  cluster_3        0.00%    passed     99.80%
#   14  cluster_12       0.00%    passed     99.81%
#   15  cluster_11       0.00%    passed     99.63%
#   16  cluster_13       0.00%    passed     99.67%
#   17  cluster_9        0.00%    passed     99.81%
# ****  TOTAL            0.00%  0 sequences failed composition chi2 test (p-value<5%; df=3)
#
# Create initial parsimony tree by phylogenetic likelihood library (PLL)... 0.001 seconds
# Generating 1000 samples for ultrafast bootstrap (seed: 941483)...
#
# NOTE: 0 MB RAM (0 GB) is required!
# Estimate model parameters (epsilon = 0.100)
# Thoroughly optimizing +I+G parameters from 10 start values...
# Init pinv, alpha: 0.000, 1.000 / Estimate: 0.000, 0.735 / LogL: -23042.247
# Init pinv, alpha: 0.110, 1.000 / Estimate: 0.110, 1.000 / LogL: -23042.191
# Init pinv, alpha: 0.220, 1.000 / Estimate: 0.220, 1.481 / LogL: -23042.163
# Init pinv, alpha: 0.331, 1.000 / Estimate: 0.331, 2.639 / LogL: -23042.151
# Init pinv, alpha: 0.441, 1.000 / Estimate: 0.441, 9.278 / LogL: -23042.143
# Init pinv, alpha: 0.551, 1.000 / Estimate: 0.551, 998.422 / LogL: -23042.150
# Init pinv, alpha: 0.661, 1.000 / Estimate: 0.661, 998.439 / LogL: -23042.241
# Init pinv, alpha: 0.772, 1.000 / Estimate: 0.772, 998.444 / LogL: -23042.588
# Init pinv, alpha: 0.882, 1.000 / Estimate: 0.882, 998.446 / LogL: -23044.090
# Init pinv, alpha: 0.992, 1.000 / Estimate: 0.950, 998.447 / LogL: -23051.101
# Optimal pinv,alpha: 0.441, 9.278 / LogL: -23042.143
#
# Parameters optimization took 0.088 sec
#
# WARNING: Estimated model parameters are at boundary that can cause numerical instability!
#
# Computing ML distances based on estimated model parameters...
# Computing ML distances took 0.001761 sec (of wall-clock time) 0.001652 sec(of CPU time)
# Computing RapidNJ tree took 0.000250 sec (of wall-clock time) 0.000000 sec (of CPU time)
# Log-likelihood of RapidNJ tree: -23042.531
# --------------------------------------------------------------------
# |             INITIALIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Generating 98 parsimony trees... 0.028 second
# Computing log-likelihood of 98 initial trees ... 0.030 seconds
# Current best score: -23042.143
#
# Do NNI search on 20 best initial trees
# Estimate model parameters (epsilon = 0.100)
#
# WARNING: Estimated model parameters are at boundary that can cause numerical instability!
#
# BETTER TREE FOUND at iteration 1: -23042.142
# BETTER TREE FOUND at iteration 6: -23042.142
# BETTER TREE FOUND at iteration 10: -23042.142
# Iteration 10 / LogL: -23042.142 / Time: 0h:0m:0s
# Iteration 20 / LogL: -23042.142 / Time: 0h:0m:0s
# Finish initializing candidate tree set (20)
# Current best tree score: -23042.142 / CPU time: 0.112
# Number of iterations: 20
# --------------------------------------------------------------------
# |               OPTIMIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Iteration 30 / LogL: -23042.142 / Time: 0h:0m:0s (0h:0m:0s left)
# BETTER TREE FOUND at iteration 35: -23042.142
# Iteration 40 / LogL: -23042.142 / Time: 0h:0m:0s (0h:0m:0s left)
# BETTER TREE FOUND at iteration 50: -23042.142
# Iteration 50 / LogL: -23042.142 / Time: 0h:0m:0s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.071
# BETTER TREE FOUND at iteration 56: -23042.142
# Iteration 60 / LogL: -23042.204 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 70 / LogL: -23042.142 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 80 / LogL: -23042.142 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 90 / LogL: -23042.160 / Time: 0h:0m:0s (0h:0m:0s left)
# BETTER TREE FOUND at iteration 93: -23042.142
# Iteration 100 / LogL: -23042.180 / Time: 0h:0m:0s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.071
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.916
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# BETTER TREE FOUND at iteration 105: -23042.142
# BETTER TREE FOUND at iteration 108: -23042.142
# Iteration 110 / LogL: -23042.158 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 120 / LogL: -23042.230 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 130 / LogL: -23206.293 / Time: 0h:0m:1s (0h:0m:0s left)
# BETTER TREE FOUND at iteration 139: -23042.142
# Iteration 140 / LogL: -23042.191 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 150 / LogL: -23042.216 / Time: 0h:0m:1s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.071
# Iteration 160 / LogL: -23042.172 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 170 / LogL: -23049.894 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 180 / LogL: -23042.172 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 190 / LogL: -23042.202 / Time: 0h:0m:1s (0h:0m:0s left)
# BETTER TREE FOUND at iteration 192: -23042.142
# Iteration 200 / LogL: -23042.185 / Time: 0h:0m:1s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.226
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.830
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# BETTER TREE FOUND at iteration 201: -23042.142
# Iteration 210 / LogL: -23042.173 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 220 / LogL: -23042.190 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 230 / LogL: -23240.834 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 240 / LogL: -23042.168 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 250 / LogL: -23042.142 / Time: 0h:0m:2s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.308
# Iteration 260 / LogL: -23042.212 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 270 / LogL: -23057.952 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 280 / LogL: -23042.207 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 290 / LogL: -23049.855 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 300 / LogL: -23042.142 / Time: 0h:0m:2s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.308
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.943
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 310 / LogL: -23042.158 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 320 / LogL: -23042.142 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 330 / LogL: -23042.192 / Time: 0h:0m:2s (0h:0m:0s left)
# UPDATE BEST LOG-LIKELIHOOD: -23042.142
# Iteration 340 / LogL: -23042.182 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 350 / LogL: -23042.185 / Time: 0h:0m:2s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.308
# Iteration 360 / LogL: -23156.159 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 370 / LogL: -23042.233 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 380 / LogL: -23156.226 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 390 / LogL: -23042.142 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 400 / LogL: -23042.142 / Time: 0h:0m:3s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.308
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.930
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 410 / LogL: -23042.142 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 420 / LogL: -23042.188 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 430 / LogL: -23049.858 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 440 / LogL: -23042.177 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 450 / LogL: -23042.195 / Time: 0h:0m:3s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.308
# Iteration 460 / LogL: -23042.166 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 470 / LogL: -23042.158 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 480 / LogL: -23042.142 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 490 / LogL: -23042.142 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 500 / LogL: -23156.158 / Time: 0h:0m:4s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.308
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.914
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 510 / LogL: -23042.200 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 520 / LogL: -23042.160 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 530 / LogL: -23042.182 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 540 / LogL: -23042.166 / Time: 0h:0m:4s (0h:0m:0s left)
# UPDATE BEST LOG-LIKELIHOOD: -23042.142
# Iteration 550 / LogL: -23042.142 / Time: 0h:0m:4s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.308
# Iteration 560 / LogL: -23042.180 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 570 / LogL: -23042.195 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 580 / LogL: -23097.317 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 590 / LogL: -23042.142 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 600 / LogL: -23042.158 / Time: 0h:0m:5s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.308
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.919
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 610 / LogL: -23042.142 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 620 / LogL: -23042.172 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 630 / LogL: -23042.211 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 640 / LogL: -23042.191 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 650 / LogL: -23065.637 / Time: 0h:0m:5s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.308
# Iteration 660 / LogL: -23042.182 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 670 / LogL: -23042.142 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 680 / LogL: -23042.142 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 690 / LogL: -23042.161 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 700 / LogL: -23042.235 / Time: 0h:0m:6s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.308
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.953
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 710 / LogL: -23042.177 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 720 / LogL: -23042.142 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 730 / LogL: -23042.142 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 740 / LogL: -23042.222 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 750 / LogL: -23042.182 / Time: 0h:0m:6s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.330
# Iteration 760 / LogL: -23042.210 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 770 / LogL: -23042.208 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 780 / LogL: -23042.180 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 790 / LogL: -23042.180 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 800 / LogL: -23042.142 / Time: 0h:0m:7s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.330
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.970
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 810 / LogL: -23042.142 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 820 / LogL: -23042.180 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 830 / LogL: -23042.209 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 840 / LogL: -23042.213 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 850 / LogL: -23042.180 / Time: 0h:0m:8s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.330
# Iteration 860 / LogL: -23042.235 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 870 / LogL: -23042.158 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 880 / LogL: -23042.210 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 890 / LogL: -23042.158 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 900 / LogL: -23042.142 / Time: 0h:0m:8s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.372
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.969
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 910 / LogL: -23042.217 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 920 / LogL: -23042.195 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 930 / LogL: -23042.211 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 940 / LogL: -23042.186 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 950 / LogL: -23049.949 / Time: 0h:0m:9s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.372
# Iteration 960 / LogL: -23049.914 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 970 / LogL: -23042.209 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 980 / LogL: -23042.142 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 990 / LogL: -23049.917 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 1000 / LogL: -23042.142 / Time: 0h:0m:9s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -23066.372
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.980
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# WARNING: bootstrap analysis did not converge. You should rerun with higher number of iterations (-nm option)
# TREE SEARCH COMPLETED AFTER 1001 ITERATIONS / Time: 0h:0m:10s
#
# --------------------------------------------------------------------
# |                    FINALIZING TREE SEARCH                        |
# --------------------------------------------------------------------
# Performs final model parameters optimization
# Estimate model parameters (epsilon = 0.010)
# 1. Initial log-likelihood: -23042.142
# Optimal log-likelihood: -23042.140
# Rate parameters:  A-C: 7.46234  A-G: 39.24238  A-T: 5.62208  C-G: 1.32173  C-T: 100.00000  G-T: 1.00000
# Base frequencies:  A: 0.292  C: 0.241  G: 0.235  T: 0.232
# Proportion of invariable sites: 0.441
# Gamma shape alpha: 9.260
# Parameters optimization took 1 rounds (0.002 sec)
#
# WARNING: Estimated model parameters are at boundary that can cause numerical instability!
#
# BEST SCORE FOUND : -23042.140
# Creating bootstrap support values...
# Split supports printed to NEXUS file ../../results/phylogeny/haplotype-sequences.fa.splits.nex
# Total tree length: 0.008
#
# Total number of iterations: 1001
# CPU time used for tree search: 9.553 sec (0h:0m:9s)
# Wall-clock time used for tree search: 9.891 sec (0h:0m:9s)
# Total CPU time used: 9.692 sec (0h:0m:9s)
# Total wall-clock time used: 10.082 sec (0h:0m:10s)
#
# Computing bootstrap consensus tree...
# Reading input file ../../results/phylogeny/haplotype-sequences.fa.splits.nex...
# 17 taxa and 170 splits.
# Consensus tree written to ../../results/phylogeny/haplotype-sequences.fa.contree
# Reading input trees file ../../results/phylogeny/haplotype-sequences.fa.contree
# Log-likelihood of consensus tree: -23042.601
#
# Analysis results written to:
#   IQ-TREE report:                ../../results/phylogeny/haplotype-sequences.fa.iqtree
#   Maximum-likelihood tree:       ../../results/phylogeny/haplotype-sequences.fa.treefile
#   Likelihood distances:          ../../results/phylogeny/haplotype-sequences.fa.mldist
#
# Ultrafast bootstrap approximation results written to:
#   Split support values:          ../../results/phylogeny/haplotype-sequences.fa.splits.nex
#   Consensus tree:                ../../results/phylogeny/haplotype-sequences.fa.contree
#   Screen log file:               ../../results/phylogeny/haplotype-sequences.fa.log
#
# Date and Time: Mon Apr  3 11:22:12 2023
# 0
