# %% [markdown]
# # Phylogenetic Analysis
#
# The goal of this notebook is to perform phylogenetic inference on the haplotypes identified in the brain.
#
# **Requirements:**
# Make sure you have `Biopython`, `MAFFT`, and `ETE3` installed in your environment.

# %%
import os 
import pandas as pd
import numpy as np
from copy import deepcopy
from subprocess import call 
from Bio import SeqIO, AlignIO, SeqRecord, Seq
from Bio.Align.Applications import MafftCommandline 

# from ete3 import Tree, TreeStyle, NodeStyle, TextFace, SequenceFace, CircleFace, faces, AttrFace

# %%
# Path to output directory
outpath = "../../results/phylogeny"

if not os.path.exists(outpath):
    os.mkdir(outpath)

# %% [markdown]
# ## Make haplotypes from mutations
#
# I'll take the mutations from the variant calling analysis and make the haplotypes using the reference genome.

# %%
# SSPE reference
reference = [base for record in SeqIO.parse("../../config/ref/MeVChiTok-SSPE.fa", "fasta") for base in record.seq]

# Import the mutations
haplotypes_df = pd.read_csv("../../results/variants/validated_variants.csv")

# We only need the mutations that have been assigned to a haplotype
haplotypes_df = haplotypes_df[~haplotypes_df.Haplotype.isin(['subclonal', 'both'])]

haplotypes_df.head()
# Out:
#     POS REF ALT      AF      DP      Effect Gene_Name  AA_Change Accession  \
# 0   537   T   C  0.3265  132284    Missense         N  Ser144Pro    SSPE_1
# 1   684   C   T  0.1140  127945  Synonymous         N  Leu193Leu    SSPE_1
# 5  1328   T   C  0.6809  131283  Synonymous         N  Ser407Ser    SSPE_1
# 7  1632   G   A  0.3126  121322    Missense         N  Gly509Ser    SSPE_1
# 9  2139   T   C  0.6473   62808  Synonymous     P/V/C  His111His    SSPE_1
#
#    Tissue     SNP   Gene Background   Haplotype Proposed_Background  \
# 0  SSPE 1   T537C      N   genome-2    genome-2             unknown
# 1  SSPE 1   C684T      N   genome-1   cluster 1             unknown
# 5  SSPE 1  T1328C      N   genome-1  genome-1-1             unknown
# 7  SSPE 1  G1632A      N   genome-2   cluster 7             unknown
# 9  SSPE 1  T2139C  P/V/C   genome-1    genome-1             unknown
#
#   Haplotype_Name
# 0       genome 2
# 1      cluster 1
# 5       genome 1
# 7     cluster 11
# 9      genome 01

# %%
def make_haplotype(haplotype_name, reference):
    """
    Add the SNPs the reference to make a haplotype.
    """
    
    assert haplotype_name in set(haplotypes_df.Haplotype_Name.to_list())
    
    # SNPs for a given haplotype
    snps_df = haplotypes_df[haplotypes_df.Haplotype_Name == haplotype_name]
    
    # get a list of tuples for the SNPs
    snps = [(pos, alt) for pos, alt in zip(snps_df.POS, snps_df.ALT)]
    
    # Copy the reference 
    haplotype = deepcopy(reference)
    
    # Change the mutation in the list.
    for pos, alt in snps:
        haplotype[pos + 1] = alt
        
    return haplotype

# %% [markdown]
# ### Haplotype Relationship
#
# ![haplotypes](example_tree.png)

# %% [markdown]
# I'll make the fasta files for each haplotype by cumulativley building them alone the above tree. Starting with the main backgrounds (Genome-1 and Genome-2)

# %%
# 1. Make genome-1 and genome-2
genome_1 = make_haplotype("genome 01", reference)
genome_2 = make_haplotype("genome 2", reference)

# %% [markdown]
# Then, I'll add the main branch-point from Genome-1

# %%
# 2. Make genome-1-1 and cluster 6
genome_1_1 = make_haplotype("genome 1", genome_1)
cluster_6 = make_haplotype("cluster 6", genome_1)

# %% [markdown]
# Then I'll add the Genome-1-1 children nodes

# %%
# 4. Make genome-1-1 children 
cluster_1 = make_haplotype("cluster 1", genome_1_1)
cluster_2 = make_haplotype("cluster 2", genome_1_1)
cluster_4 = make_haplotype("cluster 4", genome_1_1)
cluster_5 = make_haplotype("cluster 5", genome_1_1)
cluster_7 = make_haplotype("cluster 7", genome_1_1)
cluster_8 = make_haplotype("cluster 8", genome_1_1)

# 5. Cluster 3 is descended from cluster 4
cluster_3 = make_haplotype("cluster 3", cluster_4)

# %% [markdown]
# Then, I'll add the Genome-2 children.

# %%
# 6. Make genome-2 clusters
cluster_9 = make_haplotype("cluster 9", genome_2)
cluster_10 = make_haplotype("cluster 10", genome_2)
cluster_11 = make_haplotype("cluster 11", genome_2)
cluster_12 = make_haplotype("cluster 12", genome_2)
cluster_13 = make_haplotype("cluster 13", genome_2)

# %% [markdown]
# Then, I'll write all of these out to a fasta file.

# %%
# 7. Save all the termimal nodes in a dictionary
haplotype_seqs = {
    "sspe_ancestor":"".join(nt for nt in reference),
    "genome_1":"".join(nt for nt in genome_1),
    "genome_2":"".join(nt for nt in genome_2),
    "genome_1_1":"".join(nt for nt in genome_1_1),
    "cluster_1":"".join(nt for nt in cluster_1),
    "cluster_2":"".join(nt for nt in cluster_2),
    "cluster_3":"".join(nt for nt in cluster_3),
    "cluster_4":"".join(nt for nt in cluster_4),
    "cluster_5":"".join(nt for nt in cluster_5),
    "cluster_6":"".join(nt for nt in cluster_6),
    "cluster_7":"".join(nt for nt in cluster_7),
    "cluster_8":"".join(nt for nt in cluster_8),
    "cluster_9":"".join(nt for nt in cluster_9),
    "cluster_10":"".join(nt for nt in cluster_10),
    "cluster_11":"".join(nt for nt in cluster_11),
    "cluster_12":"".join(nt for nt in cluster_12),
    "cluster_13":"".join(nt for nt in cluster_13)
}

# 8. Write out to a fasta file
haplotype_records = [SeqRecord.SeqRecord(Seq.Seq(seq), id = hap) for hap, seq in haplotype_seqs.items()]
SeqIO.write(haplotype_records, os.path.join(outpath, "haplotype-sequences.fa"), "fasta")
# Out:
# 17

# %% [markdown]
# ## Visualize the Tree

# %% [markdown]
# Make a tree with the Fasta file of each terminal haplotype. These are alredady aligned by the nature of how I made them.

# %%
# Building the phylogeny with IQtree with 1000 bootstrap iterations with GTR+I+G (Invariable site plus discrete Gamma model) with asr
alignfasta = os.path.join(outpath, "haplotype-sequences.fa")
call(f"iqtree -s {alignfasta} -m GTR+I+G -bb 1000 -redo", shell=True)
# Out:
# IQ-TREE multicore version 2.1.4-beta COVID-edition for Linux 64-bit built Jun 24 2021
# Developed by Bui Quang Minh, James Barbetti, Nguyen Lam Tung,
# Olga Chernomor, Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    rhino02 (AVX512, FMA3, 754 GB RAM)
# Command: iqtree -s ../../results/phylogeny/haplotype-sequences.fa -m GTR+I+G -bb 1000 -redo
# Seed:    789293 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Thu Mar  2 20:40:40 2023
# Kernel:  AVX+FMA - 1 threads (72 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 72 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file ../../results/phylogeny/haplotype-sequences.fa ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 17 sequences with 15894 columns, 69 distinct patterns
# 47 parsimony-informative, 50 singleton sites, 15797 constant sites
#                Gap/Ambiguity  Composition  p-value
#    1  sspe_ancestor    0.00%    passed     99.27%
#    2  genome_1         0.00%    passed    100.00%
#    3  genome_2         0.00%    passed     99.78%
#    4  genome_1_1       0.00%    passed     99.84%
#    5  cluster_1        0.00%    passed     99.73%
#    6  cluster_2        0.00%    passed     99.80%
#    7  cluster_3        0.00%    passed     99.76%
#    8  cluster_4        0.00%    passed     99.89%
#    9  cluster_5        0.00%    passed     99.89%
#   10  cluster_6        0.00%    passed     99.99%
#   11  cluster_7        0.00%    passed     99.74%
#   12  cluster_8        0.00%    passed     99.80%
#   13  cluster_9        0.00%    passed     99.78%
#   14  cluster_10       0.00%    passed     99.62%
#   15  cluster_11       0.00%    passed     99.71%
#   16  cluster_12       0.00%    passed     99.84%
#   17  cluster_13       0.00%    passed     99.76%
# ****  TOTAL            0.00%  0 sequences failed composition chi2 test (p-value<5%; df=3)
# NOTE: cluster_9 is identical to genome_2 but kept for subsequent analysis
#
# Create initial parsimony tree by phylogenetic likelihood library (PLL)... 0.000 seconds
# Generating 1000 samples for ultrafast bootstrap (seed: 789293)...
#
# NOTE: 0 MB RAM (0 GB) is required!
# Estimate model parameters (epsilon = 0.100)
# Thoroughly optimizing +I+G parameters from 10 start values...
# Init pinv, alpha: 0.000, 1.000 / Estimate: 0.000, 0.133 / LogL: -22895.760
# Init pinv, alpha: 0.110, 1.000 / Estimate: 0.110, 0.204 / LogL: -22895.731
# Init pinv, alpha: 0.221, 1.000 / Estimate: 0.221, 0.295 / LogL: -22895.713
# Init pinv, alpha: 0.331, 1.000 / Estimate: 0.331, 0.431 / LogL: -22895.707
# Init pinv, alpha: 0.442, 1.000 / Estimate: 0.442, 0.668 / LogL: -22895.702
# Init pinv, alpha: 0.552, 1.000 / Estimate: 0.552, 1.210 / LogL: -22895.699
# Init pinv, alpha: 0.663, 1.000 / Estimate: 0.663, 3.722 / LogL: -22895.695
# Init pinv, alpha: 0.773, 1.000 / Estimate: 0.773, 998.431 / LogL: -22895.712
# Init pinv, alpha: 0.883, 1.000 / Estimate: 0.883, 998.444 / LogL: -22896.215
# Init pinv, alpha: 0.994, 1.000 / Estimate: 0.967, 998.447 / LogL: -22902.602
# Optimal pinv,alpha: 0.663, 3.722 / LogL: -22895.695
#
# Parameters optimization took 0.086 sec
# Computing ML distances based on estimated model parameters...
# Computing ML distances took 0.006255 sec (of wall-clock time) 0.006256 sec(of CPU time)
# WARNING: Some pairwise ML distances are too long (saturated)
# Computing RapidNJ tree took 0.000216 sec (of wall-clock time) 0.000232 sec (of CPU time)
# Log-likelihood of RapidNJ tree: -22970.107
# --------------------------------------------------------------------
# |             INITIALIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Generating 98 parsimony trees... 0.034 second
# Computing log-likelihood of 98 initial trees ... 0.036 seconds
# Current best score: -22895.695
#
# Do NNI search on 20 best initial trees
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 1: -22895.693
# Iteration 10 / LogL: -22895.693 / Time: 0h:0m:0s
# Iteration 20 / LogL: -22895.693 / Time: 0h:0m:0s
# Finish initializing candidate tree set (20)
# Current best tree score: -22895.693 / CPU time: 0.135
# Number of iterations: 20
# --------------------------------------------------------------------
# |               OPTIMIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Iteration 30 / LogL: -22895.770 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 40 / LogL: -22895.796 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 50 / LogL: -22895.730 / Time: 0h:0m:0s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.401
# Iteration 60 / LogL: -22895.693 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 70 / LogL: -22895.787 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 80 / LogL: -22978.930 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 90 / LogL: -22895.693 / Time: 0h:0m:0s (0h:0m:0s left)
# Iteration 100 / LogL: -22895.783 / Time: 0h:0m:0s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.401
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.898
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 110 / LogL: -22895.732 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 120 / LogL: -22895.693 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 130 / LogL: -22895.728 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 140 / LogL: -22895.740 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 150 / LogL: -22895.729 / Time: 0h:0m:1s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.633
# Iteration 160 / LogL: -22895.693 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 170 / LogL: -22895.760 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 180 / LogL: -22895.693 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 190 / LogL: -22895.766 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 200 / LogL: -22895.720 / Time: 0h:0m:1s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.634
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.934
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 210 / LogL: -22895.789 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 220 / LogL: -22895.756 / Time: 0h:0m:1s (0h:0m:0s left)
# Iteration 230 / LogL: -22895.693 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 240 / LogL: -22895.768 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 250 / LogL: -22895.762 / Time: 0h:0m:2s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.517
# Iteration 260 / LogL: -22895.693 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 270 / LogL: -22895.740 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 280 / LogL: -22895.693 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 290 / LogL: -22895.723 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 300 / LogL: -22895.723 / Time: 0h:0m:2s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.517
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.979
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 310 / LogL: -22895.693 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 320 / LogL: -22895.693 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 330 / LogL: -22895.814 / Time: 0h:0m:2s (0h:0m:0s left)
# Iteration 340 / LogL: -22895.756 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 350 / LogL: -22895.742 / Time: 0h:0m:3s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.517
# Iteration 360 / LogL: -22978.861 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 370 / LogL: -22895.758 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 380 / LogL: -22895.763 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 390 / LogL: -22895.786 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 400 / LogL: -22895.760 / Time: 0h:0m:3s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.517
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.964
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 410 / LogL: -22895.693 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 420 / LogL: -22895.693 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 430 / LogL: -22895.749 / Time: 0h:0m:3s (0h:0m:0s left)
# Iteration 440 / LogL: -22895.693 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 450 / LogL: -22895.736 / Time: 0h:0m:4s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.696
# Iteration 460 / LogL: -22895.752 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 470 / LogL: -22895.757 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 480 / LogL: -22895.693 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 490 / LogL: -22895.759 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 500 / LogL: -22895.760 / Time: 0h:0m:4s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.696
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.957
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 510 / LogL: -22895.693 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 520 / LogL: -22895.750 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 530 / LogL: -22895.789 / Time: 0h:0m:4s (0h:0m:0s left)
# Iteration 540 / LogL: -22895.794 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 550 / LogL: -22895.693 / Time: 0h:0m:5s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.696
# Iteration 560 / LogL: -22895.794 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 570 / LogL: -22895.693 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 580 / LogL: -22895.736 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 590 / LogL: -22895.776 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 600 / LogL: -22895.723 / Time: 0h:0m:5s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.696
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.968
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 610 / LogL: -22895.723 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 620 / LogL: -22895.776 / Time: 0h:0m:5s (0h:0m:0s left)
# Iteration 630 / LogL: -22895.749 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 640 / LogL: -22895.751 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 650 / LogL: -22895.800 / Time: 0h:0m:6s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.719
# Iteration 660 / LogL: -22895.747 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 670 / LogL: -22895.693 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 680 / LogL: -22895.693 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 690 / LogL: -22895.756 / Time: 0h:0m:6s (0h:0m:0s left)
# Iteration 700 / LogL: -22895.756 / Time: 0h:0m:6s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.719
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.981
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 710 / LogL: -22895.756 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 720 / LogL: -22895.768 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 730 / LogL: -22895.693 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 740 / LogL: -22895.730 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 750 / LogL: -22895.749 / Time: 0h:0m:7s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.719
# Iteration 760 / LogL: -22895.693 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 770 / LogL: -22895.693 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 780 / LogL: -22895.693 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 790 / LogL: -22895.749 / Time: 0h:0m:7s (0h:0m:0s left)
# Iteration 800 / LogL: -22895.781 / Time: 0h:0m:8s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.719
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.978
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 810 / LogL: -22895.823 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 820 / LogL: -22895.732 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 830 / LogL: -22895.751 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 840 / LogL: -22895.745 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 850 / LogL: -22895.693 / Time: 0h:0m:8s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.875
# Iteration 860 / LogL: -22895.784 / Time: 0h:0m:8s (0h:0m:0s left)
# Iteration 870 / LogL: -22895.784 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 880 / LogL: -22895.732 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 890 / LogL: -22895.723 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 900 / LogL: -22895.729 / Time: 0h:0m:9s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.875
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.973
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 910 / LogL: -22954.813 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 920 / LogL: -22895.777 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 930 / LogL: -22895.736 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 940 / LogL: -22895.745 / Time: 0h:0m:9s (0h:0m:0s left)
# Iteration 950 / LogL: -22895.787 / Time: 0h:0m:10s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.875
# Iteration 960 / LogL: -22895.748 / Time: 0h:0m:10s (0h:0m:0s left)
# Iteration 970 / LogL: -22895.723 / Time: 0h:0m:10s (0h:0m:0s left)
# Iteration 980 / LogL: -22895.693 / Time: 0h:0m:10s (0h:0m:0s left)
# Iteration 990 / LogL: -22895.693 / Time: 0h:0m:10s (0h:0m:0s left)
# Iteration 1000 / LogL: -22895.797 / Time: 0h:0m:10s (0h:0m:0s left)
# Log-likelihood cutoff on original alignment: -22906.875
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.981
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# WARNING: bootstrap analysis did not converge. You should rerun with higher number of iterations (-nm option)
# TREE SEARCH COMPLETED AFTER 1001 ITERATIONS / Time: 0h:0m:10s
#
# --------------------------------------------------------------------
# |                    FINALIZING TREE SEARCH                        |
# --------------------------------------------------------------------
# Performs final model parameters optimization
# Estimate model parameters (epsilon = 0.010)
# 1. Initial log-likelihood: -22895.693
# Optimal log-likelihood: -22895.690
# Rate parameters:  A-C: 2.57807  A-G: 1.12159  A-T: 0.95501  C-G: 1.47915  C-T: 3.00643  G-T: 1.00000
# Base frequencies:  A: 0.291  C: 0.241  G: 0.235  T: 0.233
# Proportion of invariable sites: 0.663
# Gamma shape alpha: 3.734
# Parameters optimization took 1 rounds (0.002 sec)
# BEST SCORE FOUND : -22895.690
# Creating bootstrap support values...
# Split supports printed to NEXUS file ../../results/phylogeny/haplotype-sequences.fa.splits.nex
# Total tree length: 0.006
#
# Total number of iterations: 1001
# CPU time used for tree search: 10.380 sec (0h:0m:10s)
# Wall-clock time used for tree search: 10.643 sec (0h:0m:10s)
# Total CPU time used: 10.520 sec (0h:0m:10s)
# Total wall-clock time used: 10.804 sec (0h:0m:10s)
#
# Computing bootstrap consensus tree...
# Reading input file ../../results/phylogeny/haplotype-sequences.fa.splits.nex...
# 17 taxa and 205 splits.
# Consensus tree written to ../../results/phylogeny/haplotype-sequences.fa.contree
# Reading input trees file ../../results/phylogeny/haplotype-sequences.fa.contree
# Log-likelihood of consensus tree: -22896.182
#
# Analysis results written to:
#   IQ-TREE report:                ../../results/phylogeny/haplotype-sequences.fa.iqtree
#   Maximum-likelihood tree:       ../../results/phylogeny/haplotype-sequences.fa.treefile
#   Likelihood distances:          ../../results/phylogeny/haplotype-sequences.fa.mldist
#
# Ultrafast bootstrap approximation results written to:
#   Split support values:          ../../results/phylogeny/haplotype-sequences.fa.splits.nex
#   Consensus tree:                ../../results/phylogeny/haplotype-sequences.fa.contree
#   Screen log file:               ../../results/phylogeny/haplotype-sequences.fa.log
#
# Date and Time: Thu Mar  2 20:40:51 2023
# 0
